# %% [markdown]
# # <a id='toc1_'></a>[**COVIDCast: EDA of Covid Data**](#toc0_)
#
# Sam Celarek
# Data Science
# scelarek@gmail.com
# August 4th, 2023

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [**COVIDCast: EDA of Covid Data**](#toc1_)
# - [Setup](#toc2_)
# - [Exploratory Data Analysis](#toc3_)
#     - [Univariate Analysis](#toc3_1_1_)
#     - [ACF and PACF](#toc3_1_2_)
#     - [Bivariate Analysis](#toc3_1_3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc2_'></a>[Setup](#toc0_)

# %% [markdown]
# These are the necessary libraries to import

# %%
from capstone_functions import *
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')

# Set the random.seed(42)
np.random.seed(42)
# Out:
# Versions used in this notebook:
# Python version: 3.9.17 (main, Jul  5 2023, 21:22:06) [MSC v.1916 64 bit (AMD64)]
# Pandas version: 2.0.2
# Numpy version: 1.23.4
# Seaborn version: 0.12.2
# Matplotlib version: 3.7.1
# Scipy version: 1.10.1
# Statsmodels version: 0.14.0
# SKLearn version: 1.2.2
# C:\Users\Samsickle\AppData\Local\Temp\ipykernel_20496\806417265.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # <a id='toc3_'></a>[Exploratory Data Analysis](#toc0_)

# %% [markdown]
# ### <a id='toc3_1_1_'></a>[Univariate Analysis](#toc0_)

# %% [markdown]
# Non-Numerical Features:

# %%
master_df = pd.read_parquet("../Data/master_df.parquet")

# Import the function to load the Iris dataset from sklearn.datasets
dfSummary(master_df, is_collapsible=True)

master_df.to_csv("../Data/master_df.csv", index=True)

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1131 entries, 2020-02-15 to 2023-03-21
# Data columns (total 66 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   new_confirmed                         1131 non-null   int32
#  1   new_hospitalized_patients             944 non-null    float64
#  2   current_hospitalized_patients         1131 non-null   float64
#  3   current_intensive_care_patients       1131 non-null   float64
#  4   new_fatal                             1131 non-null   int32
#  5   average_temperature_celsius           943 non-null    float64
#  6   cancel_events                         1131 non-null   float32
#  7   confirmed                             1131 non-null   int32
#  8   cumulative_hospitalized_patients      944 non-null    float64
#  9   derived_reproduction_rate             1131 non-null   float64
#  10  dew_point                             943 non-null    float64
#  11  excess_mortality                      1131 non-null   float64
#  12  excess_mortality_cumulative           1131 non-null   float64
#  13  excess_mortality_cumulative_absolute  1131 non-null   float64
#  14  facial_coverings                      874 non-null    float64
#  15  fatal                                 1131 non-null   int32
#  16  gatherings_restrictions               1131 non-null   float32
#  17  infected                              1131 non-null   int32
#  18  information_campaigns                 1131 non-null   float32
#  19  internal_movement_restrictions        1131 non-null   float32
#  20  international_movement_restrictions   1131 non-null   float32
#  21  kap_mortality_rate                    1131 non-null   float64
#  22  maximum_temperature_celsius           943 non-null    float64
#  23  minimum_temperature_celsius           943 non-null    float64
#  24  mobility_grocery_and_pharmacy         941 non-null    float64
#  25  mobility_parks                        941 non-null    float64
#  26  mobility_residential                  941 non-null    float64
#  27  mobility_retail_and_recreation        941 non-null    float64
#  28  mobility_transit_stations             941 non-null    float64
#  29  mobility_workplaces                   941 non-null    float64
#  30  new_recovered                         1131 non-null   int32
#  31  new_susceptible                       1131 non-null   float32
#  32  new_tests                             855 non-null    float32
#  33  new_vaccinations                      1131 non-null   float64
#  34  people_fully_vaccinated               1131 non-null   float64
#  35  people_vaccinated                     1131 non-null   float64
#  36  positive_rate                         855 non-null    float64
#  37  rainfall_mm                           943 non-null    float64
#  38  recovered                             1131 non-null   int32
#  39  relative_humidity                     943 non-null    float64
#  40  rho_transmission_rate                 1131 non-null   float64
#  41  school_closing                        1131 non-null   float32
#  42  sig_recovery_rate                     1131 non-null   float64
#  43  snowfall_mm                           943 non-null    float64
#  44  stay_home_restrictions                1131 non-null   float32
#  45  stringency_index                      1131 non-null   float32
#  46  susceptible                           1131 non-null   float32
#  47  t/k_mortality_period                  1131 non-null   float64
#  48  t/r_infection_period                  1131 non-null   float64
#  49  t/s_recovery_period                   1131 non-null   float64
#  50  testing_policy                        1131 non-null   float32
#  51  tests_per_case                        855 non-null    float64
#  52  total_boosters                        930 non-null    float64
#  53  total_removed                         1131 non-null   int32
#  54  total_tests                           855 non-null    float32
#  55  total_vaccinations                    1131 non-null   float64
#  56  transport_closing                     1131 non-null   float32
#  57  vaccination_policy                    874 non-null    float64
#  58  workplace_closing                     1131 non-null   float32
#  59  dayofweek                             1131 non-null   int32
#  60  quarter                               1131 non-null   int32
#  61  month                                 1131 non-null   int32
#  62  year                                  1131 non-null   int32
#  63  dayofyear                             1131 non-null   int32
#  64  dayofmonth                            1131 non-null   int32
#  65  new_bi_weekly_vaccinations            1131 non-null   float64
# dtypes: float32(15), float64(37), int32(14)
# memory usage: 463.9 KB

# %%
target_columns = ['new_hospitalized_patients', 'new_fatal', 'new_confirmed']

master_df[target_columns].corr('spearman').style.background_gradient(cmap='coolwarm')

# Plotting the heatmap
plt.figure(figsize=(5, 1))  # Adjust the figure size


ax = sns.heatmap(master_df[target_columns].corr('spearman'), 
                 cmap='coolwarm', 
                 vmin=0, 
                 vmax=1, 
                 annot=True, 
                 fmt='.2f', 
                 cbar=False)

# Positioning the x-label and xticks at the top
plt.xticks([])

# Setting labels and title
plt.xlabel(' ', fontsize=14)
plt.ylabel('Target', fontsize=14)
plt.title('Target Variable Correlation Heatmap', fontsize=16, pad=20)

plt.tight_layout()
plt.show()

# %%
# Creating subplots vertically aligned
fig = make_subplots(rows=3, cols=1, shared_xaxes=True, subplot_titles=("Daily Confirmed", "Current Hospitalizations", "Daily Fatalities"))

# Adding traces for each subplot
fig.add_trace(go.Scatter(x=master_df.index, y=master_df['new_confirmed'], name='Daily Confirmed'), row=1, col=1)
fig.add_trace(go.Scatter(x=master_df.index, y=master_df['current_hospitalized_patients'], name='Current Hospitalizations'), row=2, col=1)
fig.add_trace(go.Scatter(x=master_df.index, y=master_df['new_fatal'], name='Daily Fatalities'), row=3, col=1)

# Update the layout
fig.update_layout(height=800, width=1000, title='Daily Confirmed Cases, Hospitalizations, and Fatalities over Time')
fig.update_xaxes(title_text='Date', row=3, col=1)
fig.update_yaxes(title_text='Daily Confirmed Cases', row=1, col=1)
fig.update_yaxes(title_text='Daily Hospitalizations', row=2, col=1)
fig.update_yaxes(title_text='Daily Fatalities', row=3, col=1)

fig.show()

# %%
target_columns = ['new_hospitalized_patients', 'new_fatal', 'new_confirmed']

master_df['new_confirmed_ra'] = master_df['new_confirmed'].rolling(window=7).mean()
master_df['new_hospitalized_patients_ra'] = master_df['new_hospitalized_patients'].rolling(window=7).mean()
master_df['new_fatal_ra'] = master_df['new_fatal'].rolling(window=7).mean()

master_daily = master_df[target_columns]
master_daily.head()
# Out:
#             new_hospitalized_patients  new_fatal  new_confirmed
# date
# 2020-02-15                        0.0          0              0
# 2020-02-16                        0.0          0              0
# 2020-02-17                        0.0          0             10
# 2020-02-18                        0.0          0              0
# 2020-02-19                        0.0          0              0

# %%
weekly_mean = master_df.resample('W').mean()
weekly_z_score = (weekly_mean - weekly_mean.mean()) / weekly_mean.sem()
weekly_sum = master_df.resample('W').sum()

monthly_mean = master_df.resample('M').mean()
monthly_z_score = (monthly_mean - monthly_mean.mean()) / monthly_mean.sem()
monthly_sum = master_df.resample('M').sum()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=master_df.index, y=master_df['new_confirmed_ra'], name='Confirmed (7-day RA)'), secondary_y=False)
fig.add_trace(go.Scatter(x=master_df.index, y=master_df['new_hospitalized_patients_ra'], name='Hospitalizations (7-day RA)'), secondary_y=True)
fig.add_trace(go.Scatter(x=master_df.index, y=master_df['new_fatal_ra'], name='Fatalities (7-day RA)'), secondary_y=True)

# Update the layout
fig.update_layout(title='Daily Confirmed Cases vs Hospitalizations/Deaths (with 7-day Rolling Average)',
                  xaxis_title='Date',
                  yaxis_title='Daily Confirmed Cases',
                  yaxis2_title='Hospitalizations/Deaths')

fig.update_xaxes(rangeslider_visible=True)

fig.show()

# %%
fig = px.bar(weekly_z_score.new_confirmed)

fig.update_layout(
    yaxis_title="", 
    xaxis_title="",
    title="Monthly deviation (%)",
    showlegend=False,
)
fig.show()

# %%
plt.figure(figsize=(15, 5))

# create the seasonal plot
month_plot(monthly_sum["new_confirmed"], ax=plt.gca())

plt.title("New Confirmed Covid Cases per Month")
sns.despine()
plt.show()

# %%
# Creating the seasonal difference again
master_df["weekly_difference"] = master_df["new_confirmed"].diff(7)

# Plotting the seasonal difference
fig = px.line(master_df, x=master_df.index, y="weekly_difference")

fig.update_layout(
    yaxis_title="Difference in Confirmed Cases", 
    xaxis_title="Date",
    title="Change in Confirmed Cases over Each Week",
    xaxis_rangeslider_visible=True,
    xaxis_range=["2021-01-31", "2023-09-01"]
)

fig.show()

# %%
# Performing seasonal decomposition on 'new_confirmed' column
tsa.seasonal_decompose(master_df['new_confirmed'], model='additive', period=7).plot();

# %% [markdown]
# ### <a id='toc3_1_2_'></a>[ACF and PACF](#toc0_)

# %%
def mean_absolute_percentage_error(true_values, predicted_values):
    """
    Calculate the mean absolute percentage error. 
    Find the prediction error and devide by the true value, then average.
    """
    
    error = true_values - predicted_values
    absolute_percentage_error = np.abs(error/true_values)
    mape = absolute_percentage_error.mean() * 100
    
    return mape

# sns.set_style('darkgrid')

# %%
# Adjust the figure size
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plot ACF
plot_acf(master_df['new_confirmed'].dropna(), lags=40, ax=ax[0], title="Autocorrelation Plot (ACF)")
ax[0].set_xlabel("Lag")
ax[0].set_ylabel("Autocorrelation")
ax[0].grid(True)
ax[0].tick_params(axis='both', which='major', labelsize=10)

# Plot PACF
plot_pacf(master_df['new_confirmed'].dropna(), lags=40, ax=ax[1], title="Partial Autocorrelation Plot (PACF)")
ax[1].set_xlabel("Lag")
ax[1].set_ylabel("Partial Autocorrelation")
ax[1].grid(True)
ax[1].tick_params(axis='both', which='major', labelsize=10)

plt.tight_layout()
plt.show()

# %%
# Adjust the figure size
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plot ACF
plot_acf(weekly_mean['new_confirmed'].dropna(), lags=40, ax=ax[0], title="Autocorrelation Plot (ACF)")
ax[0].set_xlabel("Lag")
ax[0].set_ylabel("Autocorrelation")
ax[0].grid(True)
ax[0].tick_params(axis='both', which='major', labelsize=10)

# Plot PACF
plot_pacf(weekly_mean['new_confirmed'].dropna(), lags=40, ax=ax[1], title="Partial Autocorrelation Plot (PACF)")
ax[1].set_xlabel("Lag")
ax[1].set_ylabel("Partial Autocorrelation")
ax[1].grid(True)
ax[1].tick_params(axis='both', which='major', labelsize=10)

plt.tight_layout()
plt.show()

# %%
# Calculate ACF and PACF
ACF = acf(master_df.new_confirmed, nlags=28)
PACF = pacf(master_df.new_confirmed, nlags=28)

# Create DataFrame
daily_grid = pd.DataFrame({'Daily ACF': ACF, 'Daily PACF': PACF})

# Plotting the heatmap
plt.figure(figsize=(4, 8))  # Adjust the figure size

ax = sns.heatmap(daily_grid[np.abs(daily_grid) > .1], 
                 cmap='coolwarm', 
                 vmin=-1, 
                 vmax=1, 
                 annot=True, 
                 fmt='.2f', 
                 cbar=False)

# Positioning the x-label and xticks at the top
ax.xaxis.set_label_position('top')
ax.xaxis.tick_top()

# Setting labels and title
plt.xlabel('Metrics', fontsize=14)
plt.ylabel('Lags', fontsize=14)
plt.title('Daily ACF & PACF Heatmap', fontsize=16, pad=20)

plt.tight_layout()
plt.show()

# %%
ACF = acf(monthly_mean.new_confirmed, nlags=12)
PACF = pacf(monthly_mean.new_confirmed, nlags=12)

monthly_grid = pd.DataFrame({'Monthly ACF': ACF, 'Monthly PACF': PACF})

monthly_grid[np.abs(monthly_grid) > .1].style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_e7f62_row0_col0, #T_e7f62_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e7f62_row1_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_e7f62_row1_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_e7f62_row2_col0, #T_e7f62_row3_col0, #T_e7f62_row3_col1, #T_e7f62_row4_col0, #T_e7f62_row5_col0, #T_e7f62_row5_col1, #T_e7f62_row6_col0, #T_e7f62_row7_col1, #T_e7f62_row10_col1, #T_e7f62_row11_col0, #T_e7f62_row11_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e7f62_row2_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_e7f62_row4_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_e7f62_row6_col1, #T_e7f62_row7_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e7f62_row8_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_e7f62_row8_col1, #T_e7f62_row9_col1, #T_e7f62_row10_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_e7f62_row9_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e7f62_row12_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_e7f62_row12_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# </style>
# <table id="T_e7f62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7f62_level0_col0" class="col_heading level0 col0" >Monthly ACF</th>
#       <th id="T_e7f62_level0_col1" class="col_heading level0 col1" >Monthly PACF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7f62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7f62_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e7f62_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7f62_row1_col0" class="data row1 col0" >0.360985</td>
#       <td id="T_e7f62_row1_col1" class="data row1 col1" >0.370741</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7f62_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_e7f62_row2_col1" class="data row2 col1" >-0.179786</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7f62_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_e7f62_row3_col1" class="data row3 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7f62_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_e7f62_row4_col1" class="data row4 col1" >0.110847</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7f62_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_e7f62_row5_col1" class="data row5 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7f62_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_e7f62_row6_col1" class="data row6 col1" >-0.125027</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e7f62_row7_col0" class="data row7 col0" >-0.130902</td>
#       <td id="T_e7f62_row7_col1" class="data row7 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e7f62_row8_col0" class="data row8 col0" >-0.134844</td>
#       <td id="T_e7f62_row8_col1" class="data row8 col1" >-0.112153</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e7f62_row9_col0" class="data row9 col0" >-0.121022</td>
#       <td id="T_e7f62_row9_col1" class="data row9 col1" >-0.115237</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e7f62_row10_col0" class="data row10 col0" >-0.110068</td>
#       <td id="T_e7f62_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e7f62_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_e7f62_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e7f62_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e7f62_row12_col0" class="data row12 col0" >0.140700</td>
#       <td id="T_e7f62_row12_col1" class="data row12 col1" >0.213936</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### <a id='toc3_1_3_'></a>[Bivariate Analysis](#toc0_)

# %%
# Compute the correlation matrix for the Iris DataFrame. This will give us the correlation coefficient between every pair of features (including the target).
# Calculate all the correlations between each independent variables
corr_df = master_df.corr('spearman')

# Mask for upper-triangular
mask = np.triu(corr_df)
plt.figure(figsize=(20,20))
sns.heatmap(corr_df.round(2), vmax=1, vmin=-1, cmap='coolwarm', mask=mask, center=0)
plt.title('Correlation Heatmap of Numeric Columns', fontsize=20)
plt.ylabel('Features', fontsize=15)
plt.xticks([])
plt.show()

# Display the correlation matrix, transposed for readability and sorted by the 'target' column. This gives us an idea of which features are most strongly correlated with the target.
# The 'style.background_gradient' method is used to apply a color gradient to the 'target' column, making it easier to visually identify high and low correlation values.
# display(correlation.T.sort_values('target').style.background_gradient(subset='target', cmap='coolwarm'))

# %% [markdown]
# $$R_0 = \frac{\text{transmission rate}}{\text{recovery rate} + \text{mortality rate}}$$

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant


redundant_features = ['new_confirmed', 'fatal', 'recovered', 'confirmed', 'people_fully_vaccinated', 'excess_mortality_cumulative_absolute', 'susceptible', 'excess_mortality_cumulative',
                                    'infected', 'total_removed', 'new_susceptible', 'people_vaccinated', 'international_movement_restrictions', 'workplace_closing',
                                    'information_campaigns', 'cancel_events', 'gatherings_restrictions', 'current_intensive_care_patients', 
                                    'testing_policy', 'stay_home_restrictions', 'new_vaccinations', 'school_closing','internal_movement_restrictions', 
                                    't/r_infection_period', 't/s_recovery_period', 't/k_mortality_period', 'new_recovered']

# Assuming in_sample_set is a DataFrame
# Add a constant term to the predictor variables for the intercept
X = add_constant(master_df.dropna(axis=1)).drop(columns=redundant_features)

# Create a DataFrame for VIF values
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns

# Calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
display(vif_data.sort_values(by='VIF', ascending=False).style.background_gradient(cmap='coolwarm', vmax=10))
# Out:
# <style type="text/css">
# #T_c1c8e_row0_col1, #T_c1c8e_row1_col1, #T_c1c8e_row2_col1, #T_c1c8e_row3_col1, #T_c1c8e_row4_col1, #T_c1c8e_row5_col1, #T_c1c8e_row6_col1, #T_c1c8e_row7_col1, #T_c1c8e_row8_col1, #T_c1c8e_row9_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c1c8e_row10_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_c1c8e_row11_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_c1c8e_row12_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_c1c8e_row13_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c1c8e_row14_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c1c8e_row15_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c1c8e_row16_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c1c8e_row17_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1c8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1c8e_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_c1c8e_level0_col1" class="col_heading level0 col1" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1c8e_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_c1c8e_row0_col0" class="data row0 col0" >dayofyear</td>
#       <td id="T_c1c8e_row0_col1" class="data row0 col1" >41008.081535</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_c1c8e_row1_col0" class="data row1 col0" >month</td>
#       <td id="T_c1c8e_row1_col1" class="data row1 col1" >40657.761623</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row2" class="row_heading level0 row2" >16</th>
#       <td id="T_c1c8e_row2_col0" class="data row2 col0" >dayofmonth</td>
#       <td id="T_c1c8e_row2_col1" class="data row2 col1" >282.332065</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_c1c8e_row3_col0" class="data row3 col0" >year</td>
#       <td id="T_c1c8e_row3_col1" class="data row3 col1" >42.065110</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_c1c8e_row4_col0" class="data row4 col0" >total_vaccinations</td>
#       <td id="T_c1c8e_row4_col1" class="data row4 col1" >26.108743</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_c1c8e_row5_col0" class="data row5 col0" >quarter</td>
#       <td id="T_c1c8e_row5_col1" class="data row5 col1" >22.820288</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_c1c8e_row6_col0" class="data row6 col0" >excess_mortality</td>
#       <td id="T_c1c8e_row6_col1" class="data row6 col1" >15.218118</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_c1c8e_row7_col0" class="data row7 col0" >current_hospitalized_patients</td>
#       <td id="T_c1c8e_row7_col1" class="data row7 col1" >14.143600</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_c1c8e_row8_col0" class="data row8 col0" >derived_reproduction_rate</td>
#       <td id="T_c1c8e_row8_col1" class="data row8 col1" >11.300894</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_c1c8e_row9_col0" class="data row9 col0" >stringency_index</td>
#       <td id="T_c1c8e_row9_col1" class="data row9 col1" >10.815693</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_c1c8e_row10_col0" class="data row10 col0" >kap_mortality_rate</td>
#       <td id="T_c1c8e_row10_col1" class="data row10 col1" >5.992146</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_c1c8e_row11_col0" class="data row11 col0" >rho_transmission_rate</td>
#       <td id="T_c1c8e_row11_col1" class="data row11 col1" >3.479585</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row12" class="row_heading level0 row12" >7</th>
#       <td id="T_c1c8e_row12_col0" class="data row12 col0" >sig_recovery_rate</td>
#       <td id="T_c1c8e_row12_col1" class="data row12 col1" >3.197578</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row13" class="row_heading level0 row13" >10</th>
#       <td id="T_c1c8e_row13_col0" class="data row13 col0" >transport_closing</td>
#       <td id="T_c1c8e_row13_col1" class="data row13 col1" >2.318353</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row14" class="row_heading level0 row14" >2</th>
#       <td id="T_c1c8e_row14_col0" class="data row14 col0" >new_fatal</td>
#       <td id="T_c1c8e_row14_col1" class="data row14 col1" >2.160851</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row15" class="row_heading level0 row15" >17</th>
#       <td id="T_c1c8e_row15_col0" class="data row15 col0" >new_bi_weekly_vaccinations</td>
#       <td id="T_c1c8e_row15_col1" class="data row15 col1" >1.584398</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row16" class="row_heading level0 row16" >11</th>
#       <td id="T_c1c8e_row16_col0" class="data row16 col0" >dayofweek</td>
#       <td id="T_c1c8e_row16_col1" class="data row16 col1" >1.074669</td>
#     </tr>
#     <tr>
#       <th id="T_c1c8e_level0_row17" class="row_heading level0 row17" >0</th>
#       <td id="T_c1c8e_row17_col0" class="data row17 col0" >const</td>
#       <td id="T_c1c8e_row17_col1" class="data row17 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
master_df.corr('spearman')['new_confirmed']\
    .sort_values(ascending=False).to_frame().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c6c6d_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c6c6d_row1_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_c6c6d_row2_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_c6c6d_row3_col0, #T_c6c6d_row4_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_c6c6d_row5_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_c6c6d_row6_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_c6c6d_row7_col0 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_c6c6d_row8_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_c6c6d_row9_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_c6c6d_row10_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_c6c6d_row11_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_c6c6d_row12_col0, #T_c6c6d_row13_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_c6c6d_row14_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c6c6d_row15_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_c6c6d_row16_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_c6c6d_row17_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_c6c6d_row18_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_c6c6d_row19_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_c6c6d_row20_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c6c6d_row21_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c6c6d_row22_col0, #T_c6c6d_row23_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_c6c6d_row24_col0, #T_c6c6d_row25_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_c6c6d_row26_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_c6c6d_row27_col0, #T_c6c6d_row28_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_c6c6d_row29_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_c6c6d_row30_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_c6c6d_row31_col0, #T_c6c6d_row32_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_c6c6d_row33_col0, #T_c6c6d_row34_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c6c6d_row35_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_c6c6d_row36_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c6c6d_row37_col0, #T_c6c6d_row38_col0, #T_c6c6d_row39_col0, #T_c6c6d_row40_col0, #T_c6c6d_row41_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c6c6d_row42_col0, #T_c6c6d_row43_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c6c6d_row44_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c6c6d_row45_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c6c6d_row46_col0, #T_c6c6d_row47_col0, #T_c6c6d_row48_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c6c6d_row49_col0, #T_c6c6d_row50_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c6c6d_row51_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_c6c6d_row52_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_c6c6d_row53_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c6c6d_row54_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c6c6d_row55_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c6c6d_row56_col0, #T_c6c6d_row57_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_c6c6d_row58_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_c6c6d_row59_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c6c6d_row60_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_c6c6d_row61_col0, #T_c6c6d_row62_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_c6c6d_row63_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c6c6d_row64_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c6c6d_row65_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c6c6d_row66_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c6c6d_row67_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_c6c6d_row68_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_c6c6d_row69_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6c6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6c6d_level0_col0" class="col_heading level0 col0" >new_confirmed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6c6d_level0_row0" class="row_heading level0 row0" >new_confirmed</th>
#       <td id="T_c6c6d_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row1" class="row_heading level0 row1" >new_tests</th>
#       <td id="T_c6c6d_row1_col0" class="data row1 col0" >0.835253</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row2" class="row_heading level0 row2" >new_hospitalized_patients</th>
#       <td id="T_c6c6d_row2_col0" class="data row2 col0" >0.795200</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row3" class="row_heading level0 row3" >infected</th>
#       <td id="T_c6c6d_row3_col0" class="data row3 col0" >0.780973</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row4" class="row_heading level0 row4" >new_confirmed_ra</th>
#       <td id="T_c6c6d_row4_col0" class="data row4 col0" >0.774539</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row5" class="row_heading level0 row5" >new_hospitalized_patients_ra</th>
#       <td id="T_c6c6d_row5_col0" class="data row5 col0" >0.765976</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row6" class="row_heading level0 row6" >new_fatal</th>
#       <td id="T_c6c6d_row6_col0" class="data row6 col0" >0.662512</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row7" class="row_heading level0 row7" >current_hospitalized_patients</th>
#       <td id="T_c6c6d_row7_col0" class="data row7 col0" >0.643971</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row8" class="row_heading level0 row8" >current_intensive_care_patients</th>
#       <td id="T_c6c6d_row8_col0" class="data row8 col0" >0.559187</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row9" class="row_heading level0 row9" >excess_mortality</th>
#       <td id="T_c6c6d_row9_col0" class="data row9 col0" >0.501404</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row10" class="row_heading level0 row10" >new_fatal_ra</th>
#       <td id="T_c6c6d_row10_col0" class="data row10 col0" >0.440875</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row11" class="row_heading level0 row11" >excess_mortality_cumulative</th>
#       <td id="T_c6c6d_row11_col0" class="data row11 col0" >0.408019</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row12" class="row_heading level0 row12" >positive_rate</th>
#       <td id="T_c6c6d_row12_col0" class="data row12 col0" >0.403736</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row13" class="row_heading level0 row13" >new_recovered</th>
#       <td id="T_c6c6d_row13_col0" class="data row13 col0" >0.402427</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row14" class="row_heading level0 row14" >new_vaccinations</th>
#       <td id="T_c6c6d_row14_col0" class="data row14 col0" >0.363972</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row15" class="row_heading level0 row15" >facial_coverings</th>
#       <td id="T_c6c6d_row15_col0" class="data row15 col0" >0.349290</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row16" class="row_heading level0 row16" >total_tests</th>
#       <td id="T_c6c6d_row16_col0" class="data row16 col0" >0.340454</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row17" class="row_heading level0 row17" >t/k_mortality_period</th>
#       <td id="T_c6c6d_row17_col0" class="data row17 col0" >0.330388</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row18" class="row_heading level0 row18" >cumulative_hospitalized_patients</th>
#       <td id="T_c6c6d_row18_col0" class="data row18 col0" >0.307759</td>
#     </tr>
#     <tr>
#       <th id="T_c6c6d_level0_row19" class="row_heading level0 row19" >transport_closing</th>
#       <td id="T_c6c6d_row19_col0" class="data row19 col0"
